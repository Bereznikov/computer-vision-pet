# %%
import csv
from pathlib import Path
from typing import Tuple, Dict

import cv2
import numpy as np
from ultralytics import YOLO

# OCR
import easyocr

# %%
# Пути и параметры

# Входное видео
VIDEO_DIR = Path("../data")
INPUT_NAME = "Автотрафик.mp4"
VIDEO_PATH = VIDEO_DIR / INPUT_NAME

# Выходы
OUTPUT_VIDEO = VIDEO_DIR / f"{VIDEO_PATH.stem}_counted.mp4"
PLATES_CSV   = VIDEO_DIR / f"{VIDEO_PATH.stem}_plates.csv"
CROSS_CSV    = VIDEO_DIR / f"{VIDEO_PATH.stem}_crossings.csv"

YOLO_WEIGHTS = "yolov8s.pt"

# Детекция только машин (COCO: car = 2)
CAR_CLASS_ID = 2
CONF_THRES = 0.5
IOU_THRES  = 0.5

# Диагональная линия: позже вычислим от размеров кадра (0.1W,0.9H) -> (0.9W,0.1H)
LINE_START_RATIO = (0.10, 0.05)  # (x_ratio, y_ratio)
LINE_END_RATIO   = (0.95, 0.95)

# В каком направлении считаем пересечение:
# Для вектора (line_start -> line_end) учитываем только переход "с левой стороны" -> "на правую"
COUNT_DIRECTION_LEFT_TO_RIGHT = True

# OCR: распознаём 1 раз на трек (или несколько попыток)
OCR_LANGS = ['en', 'ru']
OCR_MAX_ATTEMPTS_PER_ID = 3  # ограничение попыток OCR на один ID (чтобы не тормозить)

# %%
# ЯЧЕЙКА 2 — Хелперы

def point_side_sign(point: Tuple[float, float], a: Tuple[float, float], b: Tuple[float, float]) -> int:
    """
    Знак ориентации точки относительно направленного отрезка a->b.
    >0: точка слева от направления (a->b)
    <0: точка справа
     0: на линии (коллинеарна)
    """
    (px, py) = point
    (ax, ay) = a
    (bx, by) = b
    cross = (bx - ax) * (py - ay) - (by - ay) * (px - ax)
    if cross > 0:
        return 1
    elif cross < 0:
        return -1
    else:
        return 0

def clamp_box(x1, y1, x2, y2, w, h):
    """Обрезка бокса к границам кадра."""
    x1 = max(0, min(int(x1), w - 1))
    y1 = max(0, min(int(y1), h - 1))
    x2 = max(0, min(int(x2), w - 1))
    y2 = max(0, min(int(y2), h - 1))
    if x2 <= x1: x2 = min(x1 + 1, w - 1)
    if y2 <= y1: y2 = min(y1 + 1, h - 1)
    return x1, y1, x2, y2

def preprocess_for_ocr(roi_bgr):
    """Небольшая предобработка ROI: в серый + порог Отсу (инверсия)."""
    gray = cv2.cvtColor(roi_bgr, cv2.COLOR_BGR2GRAY)
    # Подавление шума
    gray = cv2.bilateralFilter(gray, d=7, sigmaColor=50, sigmaSpace=50)
    # Порог
    _, thr = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
    return thr

def draw_label(img, text, org, color=(0, 255, 255), scale=0.6, thickness=2):
    """Подпись с лёгкой «обводкой» для читаемости."""
    x, y = org
    cv2.putText(img, text, (x, y), cv2.FONT_HERSHEY_SIMPLEX, scale, (0,0,0), thickness+2, cv2.LINE_AA)
    cv2.putText(img, text, (x, y), cv2.FONT_HERSHEY_SIMPLEX, scale, color, thickness, cv2.LINE_AA)

# %%
# ЯЧЕЙКА 3 — Инициализация

assert VIDEO_PATH.exists(), f"Видео не найдено: {VIDEO_PATH}"

# YOLOv8
model = YOLO(YOLO_WEIGHTS)

# OCR (EasyOCR)
reader = easyocr.Reader(OCR_LANGS)

print("Готово: модель YOLO и OCR инициализированы.")
# Out:
# Готово: модель YOLO и OCR инициализированы.

# %%
# ЯЧЕЙКА 4 — Основной цикл: читаем видео, считаем пересечения, распознаём номера, записываем результат

cap = cv2.VideoCapture(str(VIDEO_PATH))
assert cap.isOpened(), "Не удалось открыть видеофайл"

fps = cap.get(cv2.CAP_PROP_FPS) or 24.0
w   = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h   = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Диагональная линия относительно размеров кадра
line_start = (int(w * LINE_START_RATIO[0]), int(h * LINE_START_RATIO[1]))
line_end   = (int(w * LINE_END_RATIO[0]), int(h * LINE_END_RATIO[1]))

# Инициализация видеозаписи
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
out = cv2.VideoWriter(str(OUTPUT_VIDEO), fourcc, fps, (w, h))

# Служебные структуры
last_side: Dict[int, int] = {}        # track_id -> (-1/0/+1) сторона относительно линии на прошлом кадре
counted_ids = set()                   # уже посчитанные ID (пересечение в нужном направлении)
cross_count = 0

plate_by_id: Dict[int, str] = {}      # распознанный номер для ID
ocr_attempts_left: Dict[int, int] = {}# осталось попыток OCR для ID
plate_rows = []                       # для CSV: (time_sec, track_id, plate_text)
cross_rows = []                       # для CSV: (time_sec, track_id)

frame_idx = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break
    frame_idx += 1

    # Детекция+трекинг (persist=True — состояние трекера сохраняется между кадрами)
    results = model.track(frame, persist=True, classes=[CAR_CLASS_ID], conf=CONF_THRES, iou=IOU_THRES)
    boxes = []
    ids   = []
    confs = []
    clss  = []

    if results and len(results) > 0 and results[0].boxes is not None and len(results[0].boxes) > 0:
        b = results[0].boxes
        # xyxy, id, conf, cls — тензоры; приводим к numpy/int
        boxes = b.xyxy.cpu().numpy()
        confs = b.conf.cpu().numpy() if b.conf is not None else np.zeros((len(boxes),))
        clss  = b.cls.cpu().numpy()  if b.cls  is not None else np.full((len(boxes),), CAR_CLASS_ID)
        if b.id is not None:
            ids = b.id.int().cpu().numpy()
        else:
            ids = np.array([-1] * len(boxes), dtype=int)

    # Рисуем диагональную линию
    cv2.line(frame, line_start, line_end, (255, 0, 0), 2)

    # Для каждого трека — центр, подсчёт, визуализация, OCR
    for i in range(len(boxes)):
        x1, y1, x2, y2 = boxes[i]
        score = float(confs[i])
        clsid = int(clss[i])
        track_id = int(ids[i])

        # Страховка по классу
        if clsid != CAR_CLASS_ID or score < CONF_THRES:
            continue

        # Центр бокса
        cx = int((x1 + x2) / 2)
        cy = int((y1 + y2) / 2)

        # Подсчёт пересечения: знак стороны относительно направленной линии (line_start -> line_end)
        side_now = point_side_sign((cx, cy), line_start, line_end)

        if track_id not in last_side.keys():
            last_side[track_id] = side_now
            # Инициализируем счётчик попыток OCR для трека
            ocr_attempts_left.setdefault(track_id, OCR_MAX_ATTEMPTS_PER_ID)
        else:
            prev = last_side[track_id]
            # Фиксируем переход слева -> справа
            if COUNT_DIRECTION_LEFT_TO_RIGHT:
                crossed_now = (prev > 0 and side_now < 0)
            else:
                crossed_now = (prev < 0 and side_now > 0)

            if crossed_now and (track_id not in counted_ids):
                counted_ids.add(track_id)
                cross_count += 1
                # отметим время события
                time_sec = (cap.get(cv2.CAP_PROP_POS_MSEC) or 0.0) / 1000.0
                cross_rows.append((f"{time_sec:.3f}", track_id))
            # Обновим сторону
            last_side[track_id] = side_now

        # Цвет бокса в зависимости от того, пересекал ли линию
        color = (0, 255, 0) if (track_id in counted_ids) else (0, 0, 255)
        x1i, y1i, x2i, y2i = clamp_box(x1, y1, x2, y2, w, h)
        cv2.rectangle(frame, (x1i, y1i), (x2i, y2i), color, 2)

        # Центр
        cv2.circle(frame, (cx, cy), 4, color, -1)

        # Подпись ID и класс
        label = f"ID {track_id} Car"
        draw_label(frame, label, (x1i, max(20, y1i - 10)), color=color)

        # OCR: если номер ещё не распознали и остались попытки — пробуем
        if (track_id not in plate_by_id) and (ocr_attempts_left.get(track_id, 0) > 0):
            roi = frame[y1i:y2i, x1i:x2i]
            if roi.size > 0:
                thr = preprocess_for_ocr(roi)
                # EasyOCR вернёт список [ (bbox, text, conf), ... ]
                results_ocr = reader.readtext(thr, detail=1)
                if results_ocr:
                    # Сортируем по уверености
                    results_ocr.sort(key=lambda x: x[2], reverse=True)
                    raw_text = results_ocr[0][1]
                    plate = "".join(ch for ch in raw_text if ch.isalnum()).upper()
                    if len(plate) >= 3:
                        plate_by_id[track_id] = plate
                        time_sec = (cap.get(cv2.CAP_PROP_POS_MSEC) or 0.0) / 1000.0
                        plate_rows.append((f"{time_sec:.3f}", track_id, plate))
                    else:
                        ocr_attempts_left[track_id] -= 1
                else:
                    ocr_attempts_left[track_id] -= 1

        # Если номер известен — показываем его
        if track_id in plate_by_id:
            draw_label(frame, plate_by_id[track_id], (x1i, max(20, y1i - 30)), color=(255, 255, 0))

    # Общий счётчик
    draw_label(frame, f"Count: {cross_count}", (10, 30), color=(0, 255, 255), scale=1.0)

    # Запись кадра
    out.write(frame)

cap.release()
out.release()

print(f"ГОТОВО: видео сохранено -> {OUTPUT_VIDEO}")
print(f"Пересечений: {cross_count}")
# Out:
# 0: 384x640 2 cars, 59.3ms
# Speed: 0.8ms preprocess, 59.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.8ms
# Speed: 0.6ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.6ms
# Speed: 0.6ms preprocess, 50.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.4ms
# Speed: 0.6ms preprocess, 50.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.0ms
# Speed: 0.6ms preprocess, 49.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.6ms
# Speed: 0.6ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.4ms
# Speed: 0.8ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.9ms
# Speed: 1.1ms preprocess, 49.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.2ms
# Speed: 0.6ms preprocess, 48.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.9ms
# Speed: 0.6ms preprocess, 49.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.8ms
# Speed: 0.6ms preprocess, 50.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 51.7ms
# Speed: 0.6ms preprocess, 51.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 51.2ms
# Speed: 0.6ms preprocess, 51.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.4ms
# Speed: 0.6ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.2ms
# Speed: 0.7ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.4ms
# Speed: 0.7ms preprocess, 49.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 76.9ms
# Speed: 0.5ms preprocess, 76.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 66.0ms
# Speed: 1.6ms preprocess, 66.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 60.3ms
# Speed: 0.6ms preprocess, 60.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 52.8ms
# Speed: 1.0ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 57.2ms
# Speed: 0.7ms preprocess, 57.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.4ms
# Speed: 0.6ms preprocess, 50.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 51.6ms
# Speed: 0.7ms preprocess, 51.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.4ms
# Speed: 0.7ms preprocess, 50.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 51.0ms
# Speed: 0.6ms preprocess, 51.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 55.3ms
# Speed: 0.8ms preprocess, 55.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 51.5ms
# Speed: 1.2ms preprocess, 51.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.5ms
# Speed: 0.6ms preprocess, 50.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.3ms
# Speed: 0.6ms preprocess, 49.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.3ms
# Speed: 0.6ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 78.1ms
# Speed: 0.7ms preprocess, 78.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 54.9ms
# Speed: 1.1ms preprocess, 54.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.1ms
# Speed: 0.6ms preprocess, 50.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 59.9ms
# Speed: 15.0ms preprocess, 59.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.4ms
# Speed: 0.6ms preprocess, 50.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.5ms
# Speed: 0.7ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.7ms
# Speed: 0.6ms preprocess, 49.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.4ms
# Speed: 0.6ms preprocess, 48.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.8ms
# Speed: 0.6ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.0ms
# Speed: 0.7ms preprocess, 50.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.6ms
# Speed: 0.7ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.9ms
# Speed: 0.6ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.2ms
# Speed: 0.6ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.0ms
# Speed: 0.6ms preprocess, 49.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 99.7ms
# Speed: 0.6ms preprocess, 99.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 51.5ms
# Speed: 0.6ms preprocess, 51.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.8ms
# Speed: 0.5ms preprocess, 50.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.8ms
# Speed: 0.6ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.9ms
# Speed: 0.7ms preprocess, 48.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.6ms
# Speed: 0.7ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 54.5ms
# Speed: 0.6ms preprocess, 54.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.6ms
# Speed: 0.6ms preprocess, 49.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.3ms
# Speed: 0.7ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.4ms
# Speed: 0.6ms preprocess, 50.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.2ms
# Speed: 0.6ms preprocess, 49.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 51.0ms
# Speed: 0.6ms preprocess, 51.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.1ms
# Speed: 0.6ms preprocess, 50.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.3ms
# Speed: 0.6ms preprocess, 49.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.7ms
# Speed: 0.6ms preprocess, 49.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.7ms
# Speed: 0.5ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.2ms
# Speed: 0.8ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.0ms
# Speed: 0.7ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.3ms
# Speed: 0.7ms preprocess, 48.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.7ms
# Speed: 0.7ms preprocess, 48.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 58.1ms
# Speed: 0.5ms preprocess, 58.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.5ms
# Speed: 0.9ms preprocess, 50.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.2ms
# Speed: 0.6ms preprocess, 50.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.8ms
# Speed: 0.7ms preprocess, 48.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.9ms
# Speed: 0.5ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.9ms
# Speed: 0.9ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 47.7ms
# Speed: 0.5ms preprocess, 47.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 48.4ms
# Speed: 0.5ms preprocess, 48.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 48.8ms
# Speed: 0.7ms preprocess, 48.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 50.9ms
# Speed: 0.6ms preprocess, 50.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 49.8ms
# Speed: 0.6ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 49.1ms
# Speed: 0.6ms preprocess, 49.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 49.6ms
# Speed: 0.6ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 50.2ms
# Speed: 0.6ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 48.5ms
# Speed: 0.5ms preprocess, 48.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 50.0ms
# Speed: 0.7ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.7ms
# Speed: 0.7ms preprocess, 49.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.9ms
# Speed: 0.8ms preprocess, 49.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.6ms
# Speed: 0.6ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.4ms
# Speed: 0.6ms preprocess, 50.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.5ms
# Speed: 0.8ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.0ms
# Speed: 0.6ms preprocess, 49.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.4ms
# Speed: 0.7ms preprocess, 48.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 51.4ms
# Speed: 0.6ms preprocess, 51.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.8ms
# Speed: 0.6ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.3ms
# Speed: 0.7ms preprocess, 49.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.2ms
# Speed: 0.6ms preprocess, 48.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 51.5ms
# Speed: 1.3ms preprocess, 51.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.2ms
# Speed: 0.6ms preprocess, 50.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 51.2ms
# Speed: 0.5ms preprocess, 51.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.3ms
# Speed: 0.6ms preprocess, 48.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.0ms
# Speed: 0.6ms preprocess, 49.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.9ms
# Speed: 0.7ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.5ms
# Speed: 0.6ms preprocess, 49.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.9ms
# Speed: 0.9ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.6ms
# Speed: 0.6ms preprocess, 50.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.1ms
# Speed: 0.7ms preprocess, 49.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.8ms
# Speed: 0.6ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.2ms
# Speed: 0.7ms preprocess, 49.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.3ms
# Speed: 0.6ms preprocess, 48.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 51.5ms
# Speed: 0.7ms preprocess, 51.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.8ms
# Speed: 0.7ms preprocess, 48.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.2ms
# Speed: 0.5ms preprocess, 48.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.7ms
# Speed: 0.7ms preprocess, 48.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 53.2ms
# Speed: 0.7ms preprocess, 53.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 54.7ms
# Speed: 0.6ms preprocess, 54.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 55.7ms
# Speed: 0.6ms preprocess, 55.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 48.1ms
# Speed: 0.6ms preprocess, 48.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.2ms
# Speed: 0.6ms preprocess, 50.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.4ms
# Speed: 0.7ms preprocess, 50.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 51.1ms
# Speed: 0.6ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.5ms
# Speed: 0.7ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.4ms
# Speed: 0.8ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.2ms
# Speed: 0.6ms preprocess, 48.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.5ms
# Speed: 0.7ms preprocess, 50.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.5ms
# Speed: 0.5ms preprocess, 50.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.2ms
# Speed: 0.7ms preprocess, 48.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 51.1ms
# Speed: 0.6ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.8ms
# Speed: 0.6ms preprocess, 48.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.5ms
# Speed: 0.6ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.7ms
# Speed: 0.6ms preprocess, 49.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.3ms
# Speed: 0.6ms preprocess, 48.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.5ms
# Speed: 0.7ms preprocess, 48.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.3ms
# Speed: 0.7ms preprocess, 49.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.9ms
# Speed: 0.5ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.5ms
# Speed: 0.8ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.8ms
# Speed: 0.7ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.4ms
# Speed: 0.6ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.6ms
# Speed: 0.7ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.1ms
# Speed: 0.8ms preprocess, 49.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.0ms
# Speed: 0.6ms preprocess, 49.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.2ms
# Speed: 0.6ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.5ms
# Speed: 0.5ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.6ms
# Speed: 0.5ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.8ms
# Speed: 0.7ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.9ms
# Speed: 0.8ms preprocess, 49.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.7ms
# Speed: 0.7ms preprocess, 50.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.8ms
# Speed: 0.5ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 52.1ms
# Speed: 0.6ms preprocess, 52.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.8ms
# Speed: 0.6ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 94.6ms
# Speed: 0.6ms preprocess, 94.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 52.3ms
# Speed: 0.6ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.9ms
# Speed: 0.6ms preprocess, 50.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.7ms
# Speed: 0.5ms preprocess, 49.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.2ms
# Speed: 1.0ms preprocess, 50.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 51.7ms
# Speed: 1.1ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.6ms
# Speed: 0.6ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.4ms
# Speed: 0.7ms preprocess, 50.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.6ms
# Speed: 0.7ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 52.4ms
# Speed: 0.6ms preprocess, 52.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 57.5ms
# Speed: 1.0ms preprocess, 57.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 51.8ms
# Speed: 0.8ms preprocess, 51.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.4ms
# Speed: 0.6ms preprocess, 50.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 53.0ms
# Speed: 0.9ms preprocess, 53.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 53.3ms
# Speed: 0.7ms preprocess, 53.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 52.3ms
# Speed: 0.8ms preprocess, 52.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.2ms
# Speed: 0.8ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 51.0ms
# Speed: 0.5ms preprocess, 51.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.5ms
# Speed: 0.6ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.4ms
# Speed: 0.7ms preprocess, 50.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.7ms
# Speed: 0.7ms preprocess, 48.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.8ms
# Speed: 0.8ms preprocess, 48.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.9ms
# Speed: 0.6ms preprocess, 49.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.0ms
# Speed: 0.7ms preprocess, 50.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.2ms
# Speed: 0.6ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.8ms
# Speed: 0.6ms preprocess, 50.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.8ms
# Speed: 0.6ms preprocess, 50.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.6ms
# Speed: 0.7ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.9ms
# Speed: 0.6ms preprocess, 49.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.5ms
# Speed: 0.8ms preprocess, 49.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.5ms
# Speed: 0.5ms preprocess, 50.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 49.6ms
# Speed: 0.6ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 49.1ms
# Speed: 0.6ms preprocess, 49.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.5ms
# Speed: 0.6ms preprocess, 50.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.6ms
# Speed: 0.7ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.1ms
# Speed: 0.5ms preprocess, 50.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.1ms
# Speed: 0.6ms preprocess, 50.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.0ms
# Speed: 0.7ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.8ms
# Speed: 0.5ms preprocess, 49.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.9ms
# Speed: 0.6ms preprocess, 48.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.5ms
# Speed: 0.9ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.4ms
# Speed: 0.8ms preprocess, 49.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.0ms
# Speed: 0.6ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 49.1ms
# Speed: 0.6ms preprocess, 49.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.8ms
# Speed: 0.6ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 49.2ms
# Speed: 0.6ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 50.9ms
# Speed: 0.6ms preprocess, 50.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 47.5ms
# Speed: 0.7ms preprocess, 47.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 48.6ms
# Speed: 0.8ms preprocess, 48.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 49.6ms
# Speed: 0.5ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 50.6ms
# Speed: 0.6ms preprocess, 50.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 49.6ms
# Speed: 0.7ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 49.9ms
# Speed: 0.6ms preprocess, 49.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 49.4ms
# Speed: 0.6ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 50.5ms
# Speed: 0.6ms preprocess, 50.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 49.7ms
# Speed: 0.7ms preprocess, 49.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 50.2ms
# Speed: 0.6ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.5ms
# Speed: 0.7ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.2ms
# Speed: 0.6ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.0ms
# Speed: 0.6ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 51.5ms
# Speed: 0.8ms preprocess, 51.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 51.1ms
# Speed: 0.6ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.1ms
# Speed: 0.8ms preprocess, 50.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.9ms
# Speed: 0.6ms preprocess, 50.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.7ms
# Speed: 0.6ms preprocess, 49.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.8ms
# Speed: 0.6ms preprocess, 49.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.8ms
# Speed: 0.6ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.2ms
# Speed: 0.8ms preprocess, 48.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.6ms
# Speed: 0.6ms preprocess, 50.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.8ms
# Speed: 0.6ms preprocess, 49.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.5ms
# Speed: 0.5ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.7ms
# Speed: 0.6ms preprocess, 49.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.5ms
# Speed: 0.7ms preprocess, 49.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 51.2ms
# Speed: 0.7ms preprocess, 51.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.2ms
# Speed: 0.6ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.9ms
# Speed: 0.6ms preprocess, 49.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.2ms
# Speed: 0.7ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.8ms
# Speed: 0.7ms preprocess, 49.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.1ms
# Speed: 0.6ms preprocess, 49.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 51.3ms
# Speed: 0.6ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.3ms
# Speed: 0.6ms preprocess, 48.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.2ms
# Speed: 0.7ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.7ms
# Speed: 0.7ms preprocess, 50.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 48.6ms
# Speed: 0.7ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.3ms
# Speed: 0.7ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.3ms
# Speed: 0.6ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 55.0ms
# Speed: 0.8ms preprocess, 55.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.7ms
# Speed: 0.7ms preprocess, 49.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.3ms
# Speed: 0.5ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.6ms
# Speed: 0.5ms preprocess, 51.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.8ms
# Speed: 0.6ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 54.0ms
# Speed: 0.7ms preprocess, 54.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 51.3ms
# Speed: 0.9ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.4ms
# Speed: 0.5ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 51.3ms
# Speed: 0.6ms preprocess, 51.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.4ms
# Speed: 0.8ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.5ms
# Speed: 1.0ms preprocess, 50.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 56.3ms
# Speed: 0.5ms preprocess, 56.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.6ms
# Speed: 0.7ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.3ms
# Speed: 0.8ms preprocess, 50.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.4ms
# Speed: 0.9ms preprocess, 49.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.4ms
# Speed: 0.6ms preprocess, 50.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 48.9ms
# Speed: 1.0ms preprocess, 48.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.7ms
# Speed: 0.6ms preprocess, 49.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 51.7ms
# Speed: 0.5ms preprocess, 51.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.4ms
# Speed: 0.6ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.9ms
# Speed: 0.9ms preprocess, 49.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.6ms
# Speed: 0.5ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.8ms
# Speed: 0.8ms preprocess, 49.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.0ms
# Speed: 0.5ms preprocess, 49.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.9ms
# Speed: 0.6ms preprocess, 49.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.7ms
# Speed: 0.6ms preprocess, 49.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.3ms
# Speed: 0.7ms preprocess, 49.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.3ms
# Speed: 0.8ms preprocess, 50.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.8ms
# Speed: 0.8ms preprocess, 49.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.0ms
# Speed: 0.6ms preprocess, 50.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.5ms
# Speed: 0.7ms preprocess, 48.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.3ms
# Speed: 0.7ms preprocess, 49.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.1ms
# Speed: 0.6ms preprocess, 49.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 52.3ms
# Speed: 0.5ms preprocess, 52.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.8ms
# Speed: 0.6ms preprocess, 49.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 48.9ms
# Speed: 0.7ms preprocess, 48.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.5ms
# Speed: 0.6ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.8ms
# Speed: 0.6ms preprocess, 50.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.4ms
# Speed: 0.6ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.6ms
# Speed: 0.7ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.8ms
# Speed: 0.6ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.5ms
# Speed: 0.7ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.4ms
# Speed: 0.6ms preprocess, 49.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.7ms
# Speed: 0.6ms preprocess, 48.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.4ms
# Speed: 0.7ms preprocess, 49.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 60.3ms
# Speed: 0.8ms preprocess, 60.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 97.2ms
# Speed: 0.8ms preprocess, 97.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 52.1ms
# Speed: 0.7ms preprocess, 52.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 56.5ms
# Speed: 0.6ms preprocess, 56.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 55.2ms
# Speed: 0.7ms preprocess, 55.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 56.2ms
# Speed: 0.6ms preprocess, 56.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 54.0ms
# Speed: 0.9ms preprocess, 54.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 52.4ms
# Speed: 0.8ms preprocess, 52.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 52.8ms
# Speed: 0.6ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 52.4ms
# Speed: 0.8ms preprocess, 52.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 52.8ms
# Speed: 0.8ms preprocess, 52.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 54.1ms
# Speed: 0.8ms preprocess, 54.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 51.1ms
# Speed: 0.9ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 55.6ms
# Speed: 0.5ms preprocess, 55.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.4ms
# Speed: 0.6ms preprocess, 50.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.4ms
# Speed: 0.8ms preprocess, 48.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.0ms
# Speed: 0.8ms preprocess, 50.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.8ms
# Speed: 0.7ms preprocess, 49.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.6ms
# Speed: 0.5ms preprocess, 49.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 51.3ms
# Speed: 0.8ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 50.2ms
# Speed: 0.6ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 51.3ms
# Speed: 0.6ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.9ms
# Speed: 0.5ms preprocess, 49.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 51.1ms
# Speed: 0.6ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.0ms
# Speed: 0.7ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 52.1ms
# Speed: 0.6ms preprocess, 52.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.6ms
# Speed: 0.6ms preprocess, 50.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.3ms
# Speed: 0.6ms preprocess, 50.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 51.1ms
# Speed: 0.7ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.1ms
# Speed: 0.6ms preprocess, 49.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.0ms
# Speed: 0.6ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.1ms
# Speed: 0.6ms preprocess, 50.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.2ms
# Speed: 0.5ms preprocess, 50.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.0ms
# Speed: 0.6ms preprocess, 49.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.1ms
# Speed: 0.5ms preprocess, 50.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.3ms
# Speed: 0.6ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.2ms
# Speed: 0.5ms preprocess, 50.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.6ms
# Speed: 0.7ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.2ms
# Speed: 0.6ms preprocess, 50.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.2ms
# Speed: 0.8ms preprocess, 51.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.6ms
# Speed: 0.8ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.9ms
# Speed: 0.6ms preprocess, 49.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.4ms
# Speed: 0.6ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.7ms
# Speed: 0.6ms preprocess, 50.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.7ms
# Speed: 0.8ms preprocess, 48.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.8ms
# Speed: 0.6ms preprocess, 48.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.3ms
# Speed: 0.6ms preprocess, 53.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.4ms
# Speed: 0.8ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.6ms
# Speed: 0.6ms preprocess, 50.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.0ms
# Speed: 0.6ms preprocess, 51.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.6ms
# Speed: 0.8ms preprocess, 50.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.3ms
# Speed: 0.6ms preprocess, 54.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.0ms
# Speed: 0.7ms preprocess, 55.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.1ms
# Speed: 0.8ms preprocess, 49.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.7ms
# Speed: 0.8ms preprocess, 48.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.0ms
# Speed: 0.6ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 55.6ms
# Speed: 0.6ms preprocess, 55.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.5ms
# Speed: 0.6ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.9ms
# Speed: 0.6ms preprocess, 49.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.9ms
# Speed: 0.7ms preprocess, 50.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.9ms
# Speed: 0.6ms preprocess, 49.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.5ms
# Speed: 0.6ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.3ms
# Speed: 0.8ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.5ms
# Speed: 0.6ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.8ms
# Speed: 0.6ms preprocess, 49.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.0ms
# Speed: 0.6ms preprocess, 50.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.6ms
# Speed: 0.6ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.6ms
# Speed: 0.5ms preprocess, 50.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.4ms
# Speed: 0.5ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.8ms
# Speed: 0.7ms preprocess, 49.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.4ms
# Speed: 0.5ms preprocess, 54.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.3ms
# Speed: 0.5ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.9ms
# Speed: 0.8ms preprocess, 48.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.1ms
# Speed: 0.6ms preprocess, 50.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.0ms
# Speed: 0.6ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.1ms
# Speed: 0.7ms preprocess, 49.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.0ms
# Speed: 0.6ms preprocess, 50.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.0ms
# Speed: 0.6ms preprocess, 50.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.8ms
# Speed: 0.8ms preprocess, 49.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.4ms
# Speed: 0.7ms preprocess, 50.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.1ms
# Speed: 0.6ms preprocess, 50.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.4ms
# Speed: 0.5ms preprocess, 50.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.4ms
# Speed: 0.6ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.4ms
# Speed: 0.6ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.1ms
# Speed: 0.6ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.0ms
# Speed: 0.8ms preprocess, 50.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.2ms
# Speed: 0.5ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.7ms
# Speed: 0.7ms preprocess, 48.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.2ms
# Speed: 0.8ms preprocess, 48.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.9ms
# Speed: 0.8ms preprocess, 49.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.5ms
# Speed: 0.6ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.3ms
# Speed: 0.6ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.3ms
# Speed: 0.7ms preprocess, 49.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 47.7ms
# Speed: 0.6ms preprocess, 47.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.5ms
# Speed: 0.7ms preprocess, 50.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.1ms
# Speed: 0.5ms preprocess, 49.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 48.6ms
# Speed: 0.7ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 48.3ms
# Speed: 0.5ms preprocess, 48.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 51.3ms
# Speed: 0.6ms preprocess, 51.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 48.7ms
# Speed: 0.7ms preprocess, 48.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 51.1ms
# Speed: 0.7ms preprocess, 51.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.9ms
# Speed: 1.0ms preprocess, 49.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.9ms
# Speed: 0.6ms preprocess, 50.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.9ms
# Speed: 0.5ms preprocess, 49.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.3ms
# Speed: 0.6ms preprocess, 49.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.1ms
# Speed: 0.6ms preprocess, 49.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.0ms
# Speed: 0.6ms preprocess, 49.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 50.3ms
# Speed: 0.6ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.1ms
# ...
#
# 0: 384x640 (no detections), 84.8ms
# Speed: 1.2ms preprocess, 84.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 104.2ms
# Speed: 1.4ms preprocess, 104.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 115.1ms
# Speed: 1.3ms preprocess, 115.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 114.1ms
# Speed: 1.6ms preprocess, 114.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 128.2ms
# Speed: 1.3ms preprocess, 128.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 112.1ms
# Speed: 1.5ms preprocess, 112.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 92.7ms
# Speed: 1.0ms preprocess, 92.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 93.2ms
# Speed: 1.0ms preprocess, 93.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 93.4ms
# Speed: 1.0ms preprocess, 93.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.9ms
# Speed: 1.2ms preprocess, 89.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 86.8ms
# Speed: 1.0ms preprocess, 86.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.9ms
# Speed: 1.0ms preprocess, 88.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 86.8ms
# Speed: 1.2ms preprocess, 86.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.9ms
# Speed: 1.3ms preprocess, 89.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.4ms
# Speed: 1.1ms preprocess, 89.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.6ms
# Speed: 0.9ms preprocess, 89.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.1ms
# Speed: 1.2ms preprocess, 90.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.0ms
# Speed: 0.9ms preprocess, 88.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.6ms
# Speed: 1.0ms preprocess, 89.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.1ms
# Speed: 0.9ms preprocess, 88.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.0ms
# Speed: 0.9ms preprocess, 90.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.2ms
# Speed: 1.0ms preprocess, 90.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 91.4ms
# Speed: 1.0ms preprocess, 91.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.7ms
# Speed: 1.4ms preprocess, 87.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.0ms
# Speed: 1.8ms preprocess, 88.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.1ms
# Speed: 1.4ms preprocess, 88.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.4ms
# Speed: 0.9ms preprocess, 87.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.0ms
# Speed: 1.0ms preprocess, 88.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.9ms
# Speed: 1.3ms preprocess, 87.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 92.9ms
# Speed: 1.1ms preprocess, 92.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.3ms
# Speed: 1.0ms preprocess, 87.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.8ms
# Speed: 0.9ms preprocess, 88.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.8ms
# Speed: 0.9ms preprocess, 88.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.8ms
# Speed: 0.8ms preprocess, 84.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.7ms
# Speed: 1.1ms preprocess, 89.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.6ms
# Speed: 0.9ms preprocess, 84.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.3ms
# Speed: 1.1ms preprocess, 87.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.1ms
# Speed: 0.9ms preprocess, 89.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.2ms
# Speed: 0.8ms preprocess, 88.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.9ms
# Speed: 0.9ms preprocess, 85.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.7ms
# Speed: 0.9ms preprocess, 88.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 86.2ms
# Speed: 1.1ms preprocess, 86.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.6ms
# Speed: 1.0ms preprocess, 89.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.9ms
# Speed: 1.6ms preprocess, 85.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.9ms
# Speed: 1.1ms preprocess, 90.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 86.8ms
# Speed: 0.9ms preprocess, 86.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.4ms
# Speed: 1.1ms preprocess, 89.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.4ms
# Speed: 1.1ms preprocess, 87.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 83.1ms
# Speed: 1.1ms preprocess, 83.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 94.7ms
# Speed: 1.8ms preprocess, 94.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.0ms
# Speed: 0.9ms preprocess, 85.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 91.2ms
# Speed: 1.2ms preprocess, 91.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.7ms
# Speed: 0.9ms preprocess, 87.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.2ms
# Speed: 1.0ms preprocess, 90.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 86.2ms
# Speed: 1.0ms preprocess, 86.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.6ms
# Speed: 1.0ms preprocess, 84.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.8ms
# Speed: 1.0ms preprocess, 89.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.9ms
# Speed: 0.9ms preprocess, 88.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.0ms
# Speed: 0.8ms preprocess, 98.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 105.6ms
# Speed: 1.1ms preprocess, 105.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 103.8ms
# Speed: 1.5ms preprocess, 103.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 126.4ms
# Speed: 1.4ms preprocess, 126.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 116.8ms
# Speed: 1.7ms preprocess, 116.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 93.7ms
# Speed: 1.2ms preprocess, 93.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 91.3ms
# Speed: 1.3ms preprocess, 91.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 98.3ms
# Speed: 1.4ms preprocess, 98.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 105.9ms
# Speed: 1.2ms preprocess, 105.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 101.8ms
# Speed: 1.5ms preprocess, 101.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 149.6ms
# Speed: 1.2ms preprocess, 149.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 93.6ms
# Speed: 0.9ms preprocess, 93.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.3ms
# Speed: 0.9ms preprocess, 90.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.1ms
# Speed: 1.0ms preprocess, 90.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.6ms
# Speed: 1.2ms preprocess, 87.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.2ms
# Speed: 0.9ms preprocess, 88.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.6ms
# Speed: 1.0ms preprocess, 89.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 91.6ms
# Speed: 0.9ms preprocess, 91.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.4ms
# Speed: 1.0ms preprocess, 90.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.3ms
# Speed: 1.4ms preprocess, 88.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.5ms
# Speed: 1.0ms preprocess, 88.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.6ms
# Speed: 1.0ms preprocess, 89.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.7ms
# Speed: 1.3ms preprocess, 87.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.8ms
# Speed: 1.0ms preprocess, 89.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.9ms
# Speed: 1.3ms preprocess, 88.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.7ms
# Speed: 0.9ms preprocess, 88.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.1ms
# Speed: 0.9ms preprocess, 87.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.9ms
# Speed: 0.9ms preprocess, 90.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 89.8ms
# Speed: 1.4ms preprocess, 89.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.4ms
# Speed: 0.9ms preprocess, 90.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.3ms
# Speed: 1.1ms preprocess, 87.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.9ms
# Speed: 1.5ms preprocess, 87.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.8ms
# Speed: 1.5ms preprocess, 88.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.2ms
# Speed: 0.8ms preprocess, 87.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 91.3ms
# Speed: 0.9ms preprocess, 91.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 90.0ms
# Speed: 1.3ms preprocess, 90.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 94.8ms
# Speed: 1.3ms preprocess, 94.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.8ms
# Speed: 1.0ms preprocess, 88.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.2ms
# Speed: 1.1ms preprocess, 88.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.7ms
# Speed: 0.9ms preprocess, 88.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.4ms
# Speed: 1.0ms preprocess, 88.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.7ms
# Speed: 0.9ms preprocess, 87.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.0ms
# Speed: 1.0ms preprocess, 85.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.4ms
# Speed: 1.0ms preprocess, 87.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.7ms
# Speed: 0.9ms preprocess, 87.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.5ms
# Speed: 1.2ms preprocess, 84.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 91.2ms
# Speed: 0.8ms preprocess, 91.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.8ms
# Speed: 1.3ms preprocess, 87.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 86.9ms
# Speed: 1.3ms preprocess, 86.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.8ms
# Speed: 1.2ms preprocess, 82.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.5ms
# Speed: 0.9ms preprocess, 88.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 82.6ms
# Speed: 1.5ms preprocess, 82.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.6ms
# Speed: 1.2ms preprocess, 88.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 84.7ms
# Speed: 1.2ms preprocess, 84.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.3ms
# Speed: 0.9ms preprocess, 87.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 85.4ms
# Speed: 1.2ms preprocess, 85.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 88.4ms
# Speed: 0.9ms preprocess, 88.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 103.7ms
# Speed: 0.9ms preprocess, 103.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 103.3ms
# Speed: 1.5ms preprocess, 103.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 103.5ms
# Speed: 1.3ms preprocess, 103.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 263.9ms
# Speed: 1.2ms preprocess, 263.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# ГОТОВО: видео сохранено -> ../data/Автотрафик_counted.mp4
# Пересечений: 5

# %%
# CSV с номерами и временем; CSV с событиями пересечения

# Номера
with open(PLATES_CSV, "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow(["time_sec", "track_id", "plate_number"])
    for row in plate_rows:
        w.writerow(list(row))

# Пересечения
with open(CROSS_CSV, "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow(["time_sec", "track_id"])
    for row in cross_rows:
        w.writerow(list(row))

print(f"CSV с номерами -> {PLATES_CSV}")
print(f"CSV с пересечениями -> {CROSS_CSV}")
# Out:
# CSV с номерами -> ../data/Автотрафик_plates.csv
# CSV с пересечениями -> ../data/Автотрафик_crossings.csv
